# %% [markdown]
# # Data Processing

# %% [markdown]
# ## 1. Load Data

# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#import dataset as data frame
lyrics = pd.read_csv('./lyrics_metrolyrics.csv')

# %% [markdown]
# ## 2. Preview Data

# %%
#data frame header
lyrics.head()
# Out:
#    index             song  year           artist genre  \
# 0      0        ego-remix  2009  beyonce-knowles   Pop
# 1      1     then-tell-me  2009  beyonce-knowles   Pop
# 2      2          honesty  2009  beyonce-knowles   Pop
# 3      3  you-are-my-rock  2009  beyonce-knowles   Pop
# 4      4    black-culture  2009  beyonce-knowles   Pop
#
#                                               lyrics
# 0  Oh baby, how you doing?\nYou know I'm gonna cu...
# 1  playin' everything so easy,\nit's like you see...
# 2  If you search\nFor tenderness\nIt isn't hard t...
# 3  Oh oh oh I, oh oh oh I\n[Verse 1:]\nIf I wrote...
# 4  Party the people, the people the party it's po...

# %%
#number of unique artists
lyrics.artist.unique().shape[0]
# Out:
# 18231

# %%
#data for game (rapper)
lyrics_game = lyrics.loc[lyrics['artist'] == 'game']
lyrics_game.head()
# Out:
#        index                      song  year artist    genre  \
# 42632  42632             beautiful-day  2009   game  Hip-Hop
# 42633  42633  better-on-the-other-side  2009   game  Hip-Hop
# 42634  42634               better-days  2009   game  Hip-Hop
# 42635  42635       flash-back-memories  2009   game  Hip-Hop
# 42636  42636               i-m-so-wavy  2009   game  Hip-Hop
#
#                                                   lyrics
# 42632  I'm in love it's a beautiful day\nI'm in love ...
# 42633  [Diddy talking]\nI remember the first time I s...
# 42634  [Chorus]\nBeen holdin' this pain inside for so...
# 42635  Play With My Cards\nhere we go,\nbait and reel...
# 42636  N-gga pop tags, I pop the fo-five\nN-gga got s...

# %% [markdown]
# ## 3. Clean Data

# %%
#notice null values
pd.isnull(lyrics_game)
# Out:
#        index   song   year  artist  genre  lyrics
# 42632  False  False  False   False  False   False
# 42633  False  False  False   False  False   False
# 42634  False  False  False   False  False   False
# 42635  False  False  False   False  False   False
# 42636  False  False  False   False  False   False
# 42637  False  False  False   False  False   False
# 42638  False  False  False   False  False   False
# 42639  False  False  False   False  False   False
# 42640  False  False  False   False  False   False
# 42641  False  False  False   False  False   False
# 42642  False  False  False   False  False   False
# 42643  False  False  False   False  False   False
# 42644  False  False  False   False  False   False
# 42645  False  False  False   False  False   False
# 42646  False  False  False   False  False   False
# 42647  False  False  False   False  False   False
# 42648  False  False  False   False  False   False
# 42649  False  False  False   False  False   False
# 42650  False  False  False   False  False   False
# 42651  False  False  False   False  False   False
# 42652  False  False  False   False  False   False
# 42653  False  False  False   False  False   False
# 42654  False  False  False   False  False   False
# 42655  False  False  False   False  False   False
# 42656  False  False  False   False  False   False
# 42657  False  False  False   False  False   False
# 42658  False  False  False   False  False   False
# 42659  False  False  False   False  False   False
# 42660  False  False  False   False  False   False
# 42661  False  False  False   False  False   False
# ...      ...    ...    ...     ...    ...     ...
# 42981  False  False  False   False  False   False
# 42982  False  False  False   False  False   False
# 42983  False  False  False   False  False   False
# 42984  False  False  False   False  False   False
# 42985  False  False  False   False  False   False
# 42986  False  False  False   False  False   False
# 42987  False  False  False   False  False   False
# 42988  False  False  False   False  False   False
# 42989  False  False  False   False  False   False
# 42990  False  False  False   False  False   False
# 42991  False  False  False   False  False   False
# 42992  False  False  False   False  False   False
# 42993  False  False  False   False  False   False
# 42994  False  False  False   False  False   False
# 42995  False  False  False   False  False   False
# 42996  False  False  False   False  False   False
# 42997  False  False  False   False  False   False
# 42998  False  False  False   False  False   False
# 42999  False  False  False   False  False   False
# 43000  False  False  False   False  False   False
# 43001  False  False  False   False  False   False
# 43002  False  False  False   False  False   False
# 43003  False  False  False   False  False   False
# 43004  False  False  False   False  False    True
# 43005  False  False  False   False  False   False
# 43006  False  False  False   False  False   False
# 43007  False  False  False   False  False   False
# 43008  False  False  False   False  False   False
# 43009  False  False  False   False  False   False
# 43010  False  False  False   False  False   False
#
# [379 rows x 6 columns]

# %%
#remove rows with null lyrics
lyrics_game = lyrics_game[pd.notnull(lyrics_game['lyrics'])]
lyrics_game.head()
# Out:
#        index                      song  year artist    genre  \
# 42632  42632             beautiful-day  2009   game  Hip-Hop
# 42633  42633  better-on-the-other-side  2009   game  Hip-Hop
# 42634  42634               better-days  2009   game  Hip-Hop
# 42635  42635       flash-back-memories  2009   game  Hip-Hop
# 42636  42636               i-m-so-wavy  2009   game  Hip-Hop
#
#                                                   lyrics
# 42632  I'm in love it's a beautiful day\nI'm in love ...
# 42633  [Diddy talking]\nI remember the first time I s...
# 42634  [Chorus]\nBeen holdin' this pain inside for so...
# 42635  Play With My Cards\nhere we go,\nbait and reel...
# 42636  N-gga pop tags, I pop the fo-five\nN-gga got s...

# %% [markdown]
# ## 4. Preview Sample

# %%
#sample of first song lyrics
demo = lyrics_game.lyrics.iloc[0]
demo
# Out:
# "I'm in love it's a beautiful day\nI'm in love it's a beautiful way\nI don't care what the weathermen say\nIt's a beautiful day (West side)\nI'm in love it's a beautiful day (We the future)\nI'm in love it's a beautiful way (We the future)\nI dont care what the weathermen say (We the future)\nIt's a beautiful day\nI'm free as a mother fucking bird I swear\nDissappearantly in air\nThere go game nigga where\nHosted on the block\nIn the black ass\nIn that all black phantom hug a block like a bear\nYeah That V12 is roaring\nFlying through the city with the pedal to the floor and\nI'm putting 26 inches on the curve\nTell the hood I'm back\nGive me the Quarter and let me serve,\nSwab, I'm still dope that's my word\nAll I did was wished the kitches and some track all on a bird\nEerb, Goddy u know I'm a murderer\nHalf these niggas beefing with me\nI never heard of them\nIf I was the old me I would murdered them\nIn matter of face if I was the old me I would hurt him still\nCourtesy, um a sleep-in west in\nI kill trash like AIDS nigga get affect\nI'm in love it's a beautiful day\nI'm in love it's a beautiful way\nI don't care what the weathermen say\nIt's a beautiful day\nI'm in love it's a beautiful day\nI'm in love it's a beautiful way\nI dont care what the weathermen say\nIt's a beautiful day\nThe dream of Hougie Newton that's what I'm living through\nThe dream of Eric White that's what I'm giving you\nWho walked through the White House without a buisness suit\nCompton hand Jerry Curl tripping around a waiting shoes\nGave Mike all my demo came here to pay my deuce\nStarted off with who can\nThen I start blazing blue\nIt was all a dream like Big said it be\nDon't sleep on me homie I bring nightmares to reality\nRap phenomenon define the rules of gravity\nStudied off classic start revising my strategy\nCause Marshal Matthers made it\nCurtis Jackson made the hell\nAnd the clouds wonderin' where the hell Marvin Gabe went\nHow do I say this I'm living for my son\nBut I can't figure out why I'm at my temple with this gun\nWake up to a Jesus piece like a Catholic nun\nTo war to be a rap legend has just begun (begun)\nI'm in love it's a beautiful day\nI'm in love it's a beautiful way\nI don't care what the weathermen say\nIt's a beautiful day\nI'm in love it's a beautiful day\nI'm in love it's a beautiful way\nI dont care what the weathermen say\nIt's a beautiful day"

# %%
#save string as txt file
f = open("./demo.txt","w+")
f.write(demo)
f.close()

# %% [markdown]
# ## 5.a. Save Data (Game)

# %%
#iterate and save through all song lyrics
n = lyrics_game.shape[0]
print("Number of songs: " + str(n))
f = open("./game/input.txt","w+")
for i in range(n):
    f.write(lyrics_game.lyrics.iloc[i])
    f.write('\n')
f.close()
# Out:
# Number of songs: 341

# %% [markdown]
# ## 5.b. Save Data (Drake)

# %%
#data for drake
lyrics_drake = lyrics.loc[lyrics['artist'] == 'drake']
#remove rows with null lyrics
lyrics_drake = lyrics_drake[pd.notnull(lyrics_drake['lyrics'])]

#iterate and save through all song lyrics
n = lyrics_drake.shape[0]
print("Number of songs: " + str(n))
f = open("./drake/input.txt","w+")
for i in range(n):
    f.write(lyrics_drake.lyrics.iloc[i])
    f.write('\n')
f.close()
# Out:
# Number of songs: 373

# %% [markdown]
# ## 5.c. Save Data (Childish Gambino)

# %%
#data for childish gambino
lyrics_childish = lyrics.loc[lyrics['artist'] == 'childish-gambino']
#remove rows with null lyrics
lyrics_childish = lyrics_childish[pd.notnull(lyrics_childish['lyrics'])]

#iterate and save through all song lyrics
n = lyrics_childish.shape[0]
print("Number of songs: " + str(n))
f = open("./childish_gambino/input.txt","w+")
for i in range(n):
    f.write(lyrics_childish.lyrics.iloc[i])
    f.write('\n')
f.close()
# Out:
# Number of songs: 130

# %% [markdown]
# ## 5.d. Save Data (Frank Ocean)

# %%
#data for frank ocean
lyrics_frank = lyrics.loc[lyrics['artist'] == 'frank-ocean']
#remove rows with null lyrics
lyrics_frank = lyrics_frank[pd.notnull(lyrics_frank['lyrics'])]

#iterate and save through all song lyrics
n = lyrics_frank.shape[0]
print("Number of songs: " + str(n))
f = open("./frank_ocean/input.txt","w+")
for i in range(n):
    f.write(lyrics_frank.lyrics.iloc[i])
    f.write('\n')
f.close()
# Out:
# Number of songs: 129

# %% [markdown]
# ## 5.e. Save Data (Rap Genre)

# %%
#data for all rap songs
lyrics_rap = lyrics.loc[lyrics['genre'] == 'Hip-Hop']
#remove rows with null lyrics
lyrics_rap = lyrics_rap[pd.notnull(lyrics_rap['lyrics'])]

#iterate and save through all song lyrics
n = lyrics_rap.shape[0]
print("Number of songs: " + str(n))

#grab a random sample of 10,000 songs
lyrics_rap = lyrics_rap.sample(frac=10000/n)
f = open("./rap_genre/input.txt","w+")
for i in range(10000):
    f.write(lyrics_rap.lyrics.iloc[i])
    f.write('\n')
f.close()
# Out:
# Number of songs: 24850
